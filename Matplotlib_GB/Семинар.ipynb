# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptops_10.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   Product        1303 non-null   object
#  2   TypeName       1303 non-null   object
#  3   Inches         1303 non-null   float64
#  4   Cpu            1303 non-null   object
#  5   Ram            1303 non-null   object
#  6   Gpu            1303 non-null   object
#  7   OpSys          1303 non-null   object
#  8   Weight         1303 non-null   float64
#  9   Price_euros    1303 non-null   float64
#  10  Cpu_Company    1303 non-null   object
#  11  Memory_Amount  1303 non-null   int64
#  12  Memory_Type    1303 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.5+ KB

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# 1            128  FlashStorage
# 2            256           SSD
# 3            512           SSD
# 4            256           SSD

# %% [markdown]
# ### Изучите количество памяти с помощью Matplotlib и hist ###

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Memory_Amount'], bins = 15);
plt.xlabel('Количество памяти')
plt.ylabel('Количество ноутбуков')
plt.title('Распределение ноутбуков по количеству памяти')
# Out:
# Text(0.5, 1.0, 'Распределение ноутбуков по количеству памяти')

# %% [markdown]
# #### Вывод: продано большинство ноутбуков с памятью до 250 GB

# %% [markdown]
# ### Изучить стоимость ноутбуков с помощью Matplotlib и hist ###

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Price_euros'], bins = 15);
plt.xlabel('Стоимость ноутбука')
plt.ylabel('Количество ноутбуков')
plt.title('Распределение ноутбуков по стоимости')
# Out:
# Text(0.5, 1.0, 'Распределение ноутбуков по стоимости')

# %% [markdown]
# ### Изучить вес ноутбуков с помощью Matplotlib и hist ###

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Weight'], bins = 15);
plt.xlabel('Вес ноутбука')
plt.ylabel('Количество ноутбуков')
plt.title('Распределение ноутбуков по весу')
# Out:
# Text(0.5, 1.0, 'Распределение ноутбуков по весу')

# %% [markdown]
# #### Вывод: основной вес проданных ноутбуков 1.0 - 2.5

# %% [markdown]
# - Постройте график
# - Назовите график
# - Сделайте именование оси x и оси y
# - Сделайте выводы

# %% [markdown]
# ### Изучите распределение типов носителя используя pie ###

# %%
# Готовим данные для графика
data = df['Memory_Type'].value_counts()
data.head()
# Out:
# Memory_Type
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: count, dtype: int64

# %%
# Строим круговую диаграмму

plt.figure(figsize=(6, 4))

plt.pie(data.values, labels = data.index, autopct='%1.1f%%')

plt.title('Распределение типов носителя')
#plt.legend(data.index);
# Out:
# Text(0.5, 1.0, 'Распределение типов носителя')

# %% [markdown]
# #### Вывод: основное количество востребованных типов носителя составляют SSD - 49.2% и HDD -44.2%

# %% [markdown]
# ### Изучите распределение компаний производителей используя bar ###

# %%
# Готовим данные для графика
data = df['Company'].value_counts()
data.head()
# Out:
# Company
# Dell      297
# Lenovo    297
# HP        274
# Asus      158
# Acer      103
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))

plt.bar(data.index, data.values)

plt.title('Распределение по компаниям производителям')
plt.xlabel('Название компании')
plt.ylabel('Количество')
plt.xticks(rotation=90);

# %% [markdown]
# #### Вывод: ноутбуков от компаний Dell, Lenovo, HP было продано значительно больше (от 500 до 270) чем остальных

# %% [markdown]
# ### Изучите распределение операционной системы используя bar ###

# %%
# Готовим данные для графика
data = df['OpSys'].value_counts().reset_index()
data.head()
# Out:
#         OpSys  count
# 0  Windows 10   1072
# 1       No OS     66
# 2       Linux     62
# 3   Windows 7     45
# 4   Chrome OS     27

# %%
plt.figure(figsize=(6, 4))

plt.bar(data['OpSys'], data['count'])

plt.title('Распределение операционной системы')
plt.xlabel('Название ОС')
plt.ylabel('Количество')
plt.xticks(rotation=90);

# %% [markdown]
# #### Вывод: ноутбуков с операциоонной системой Windows 10 было продано значительно больше (1200) чем остальных

# %% [markdown]
# ### Изучите распределение компаний производителя CPU используя pie ###

# %%
# Готовим данные для графика
data = df['Cpu_Company'].value_counts()

data.head()
# Out:
# Cpu_Company
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
# Строим круговую диаграмму

plt.figure(figsize=(6, 4))

plt.pie(data.values, labels = data.index, autopct='%1.1f%%')

plt.title('Распределение компаний производителя CPU')
#plt.legend(data.index);
# Out:
# Text(0.5, 1.0, 'Распределение компаний производителя CPU')

# %% [markdown]
# #### Вывод: самой востребованной компанией производителем CPU является Intel (95.2%)

# %% [markdown]
# ### Задание 3.
# ### Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или мнорядовую столбчатую диаграмму. Процессоры от Samsung не изучайте.

# %% [markdown]
# ### 3.1 Построить график  в абсолютных величинах используя bar

# %%
df1 = pd.crosstab(index = df['Company'], columns = df['Cpu_Company'])
df1.drop('Samsung', inplace = True, axis = 1)
df1 = df1.reset_index()
df1.head()
# Out:
# Cpu_Company Company  AMD  Intel
# 0              Acer   10     93
# 1             Apple    0     21
# 2              Asus   11    147
# 3             Chuwi    0      3
# 4              Dell    0    297

# %%
plt.figure(figsize=(8, 6))

# определяем кол-во делений
n_ticks = np.arange(len(df1['AMD']))

# определяем сдвиг
offset = 0.2

# определяем ширину столбцов
w = 0.4

# добавляем сдвиг к кол-ву делений
plt.bar(n_ticks - offset, df1['AMD'], width=w)
plt.bar(n_ticks + offset, df1['Intel'], width=w)

plt.title('Взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров')
plt.xlabel('Компании производители ноутбуков')
plt.ylabel('Кол-во процессоров')
plt.legend(['AMD', 'Intel'])
plt.xticks(n_ticks, df1['Company'], rotation = 90);  # добавляем метки делений

# %% [markdown]
# ### 3.2 Построить график в относительных величинах используя bar

# %%
df1 = pd.crosstab(index = df['Company'], columns = df['Cpu_Company'], normalize = 'index')
df1.drop('Samsung', inplace = True, axis = 1)
df1 = df1.reset_index()
df1.head()
# Out:
# Cpu_Company Company       AMD     Intel
# 0              Acer  0.097087  0.902913
# 1             Apple  0.000000  1.000000
# 2              Asus  0.069620  0.930380
# 3             Chuwi  0.000000  1.000000
# 4              Dell  0.000000  1.000000
